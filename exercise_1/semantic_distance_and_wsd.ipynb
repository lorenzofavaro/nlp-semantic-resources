# %%
import csv
import math
import nltk
from nltk.corpus import wordnet
from enum import Enum
from collections import deque

# %% [markdown]
# ### Wordnet functions

# %%
# get all hypernyms paths of a sense looping recursively on hypernyms of his ancestors
def hypernym_paths(sense):
    paths = []
    hypernyms = sense.hypernyms()
    if not hypernyms:
        return [[sense]]

    for hypernym in hypernyms:
        for ancestor_list in hypernym_paths(hypernym):
            ancestor_list.append(sense)
            ancestor_list.reverse()
            paths.append(ancestor_list)

    return paths


# maximum length of hypernym paths for a sense
def depth(sense):
    if not sense:
        return 0

    return max([len(path) for path in sense.hypernym_paths()])


def lowest_common_sense(path1, path2):
    common_senses = list(set(path1) & set(path2))

    if common_senses:
        max_depth = max(depth(s) for s in common_senses)
        min_common_senses = [s for s in common_senses if depth(s) == max_depth]
        # if there are more than 1 min_common_senses we choose the sense with the max depth from root
        return min_common_senses[0], max_depth

    return None


# first common ancestor, that is the closest hypernym to the two senses
def lowest_common_subsumer(sense1, sense2):
    sense1_hypernym_paths = hypernym_paths(sense1)
    sense2_hypernym_paths = hypernym_paths(sense2)

    max_depth = None
    lcs = None

    for path1 in sense1_hypernym_paths:
        for path2 in sense2_hypernym_paths:
            if min_tuple := lowest_common_sense(path1, path2):
                min_common_sense, depth = min_tuple
                if not lcs or (lcs and depth > max_depth):
                    max_depth = depth
                    lcs = min_common_sense

    return lcs

# Maximum depth that is the longest path of the hyperonyms of all the senses present in wordnet (for this version of wn is equal to 40)
max_depth = max(max(len(hyp_path) for hyp_path in hypernym_paths(sense)) for sense in wordnet.all_synsets())


def compute_shortest_path(sense1, sense2):
    if sense1 == sense2:
        return 0
    
    sense1_hypernym_paths = hypernym_paths(sense1)
    sense2_hypernym_paths = hypernym_paths(sense2)

    min_distance = float("inf")
    for path1 in sense1_hypernym_paths:
        for path2 in sense2_hypernym_paths:
            common_set = list(set(path1) & set(path2))
            common_dict = {elem: path1.index(elem) + path2.index(elem) for elem in common_set}

            if common_dict:
                min_common_path = min(common_dict.values())
                min_distance = min(min_common_path, min_distance)
    
    return (2 * max_depth) if math.isinf(min_distance) else min_distance

# %% [markdown]
# ### Similarity Metrics

# %%
# get max similarity among all the senses of each word
def similarity(word1, word2, metric):
    max_similarity = 0

    for sense1 in wordnet.synsets(word1):
        for sense2 in wordnet.synsets(word2):
            max_similarity = max(metric(sense1, sense2), max_similarity)

    return max_similarity

# interval: (0, 1]
def wu_palmer(sense1, sense2):
    return 2 * depth(lowest_common_subsumer(sense1,sense2)) / (depth(sense1) + depth(sense2))


# interval: (0, 2 * depthMax]
def shortest_path(sense1, sense2):
    return 2 * max_depth - compute_shortest_path(sense1, sense2)


# interval: (0, log(2 * depthMax + 1)]
def leakcock_chodorow(sense1, sense2):
    return -math.log((compute_shortest_path(sense1, sense2) + 1) / (2 * max_depth + 1)) # add 1 to avoid log(0)


class SimilarityMetrics(Enum):
    wu_palmer = wu_palmer
    shortest_path = shortest_path
    leakcock_chodorow = leakcock_chodorow

# %% [markdown]
# ### Similarity Computation

# %%
metric = SimilarityMetrics.wu_palmer
print('-----------------------------------------')
print(f'SIMILARITY METRIC: {metric.__name__}')
print('-----------------------------------------\n')

with open('data/WordSim353.csv') as f:
    csv_reader = csv.reader(f, delimiter=',')

    for index, row in enumerate(csv_reader):
        if index > 0:
            sim = similarity(row[0], row[1], metric)
            print(f'Words: \t{row[0].upper()} - {row[1].upper()}'.expandtabs(20))
            print(f'Metric similarity: \t{sim}'.expandtabs(20))
            print(f'Human similarity: \t{row[2]}\n'.expandtabs(20))
# Out:
# -----------------------------------------
# SIMILARITY METRIC: wu_palmer
# -----------------------------------------
#
# Words:              LOVE - SEX
# Metric similarity:  0.9230769230769231
# Human similarity:   6.77
#
# Words:              TIGER - CAT
# Metric similarity:  0.9655172413793104
# Human similarity:   7.35
#
# Words:              TIGER - TIGER
# Metric similarity:  1.0
# Human similarity:   10.00
#
# Words:              BOOK - PAPER
# Metric similarity:  0.875
# Human similarity:   7.46
#
# Words:              COMPUTER - KEYBOARD
# Metric similarity:  0.8235294117647058
# Human similarity:   7.62
#
# Words:              COMPUTER - INTERNET
# Metric similarity:  0.631578947368421
# Human similarity:   7.58
#
# Words:              PLANE - CAR
# Metric similarity:  0.7272727272727273
# Human similarity:   5.77
#
# Words:              TRAIN - CAR
# Metric similarity:  0.7368421052631579
# Human similarity:   6.31
#
# Words:              TELEPHONE - COMMUNICATION
# Metric similarity:  0.16666666666666666
# Human similarity:   7.50
#
# Words:              TELEVISION - RADIO
# Metric similarity:  0.9090909090909091
# Human similarity:   6.77
#
# Words:              MEDIA - RADIO
# Metric similarity:  0.8235294117647058
# Human similarity:   7.42
#
# Words:              DRUG - ABUSE
# Metric similarity:  0.16666666666666666
# Human similarity:   6.85
#
# Words:              BREAD - BUTTER
# Metric similarity:  0.75
# Human similarity:   6.19
#
# Words:              CUCUMBER - POTATO
# Metric similarity:  0.8235294117647058
# Human similarity:   5.92
#
# Words:              DOCTOR - NURSE
# Metric similarity:  0.8695652173913043
# Human similarity:   7.00
#
# Words:              PROFESSOR - DOCTOR
# Metric similarity:  0.75
# Human similarity:   6.62
#
# Words:              STUDENT - PROFESSOR
# Metric similarity:  0.6666666666666666
# Human similarity:   6.81
#
# Words:              SMART - STUDENT
# Metric similarity:  0.1111111111111111
# Human similarity:   4.62
#
# Words:              SMART - STUPID
# Metric similarity:  0.1111111111111111
# Human similarity:   5.81
#
# Words:              COMPANY - STOCK
# Metric similarity:  0.6153846153846154
# Human similarity:   7.08
#
# Words:              STOCK - MARKET
# Metric similarity:  0.5555555555555556
# Human similarity:   8.08
#
# Words:              STOCK - PHONE
# Metric similarity:  0.7
# Human similarity:   1.62
#
# Words:              STOCK - CD
# Metric similarity:  0.7368421052631579
# Human similarity:   1.31
#
# Words:              STOCK - JAGUAR
# Metric similarity:  0.8148148148148148
# Human similarity:   0.92
#
# Words:              STOCK - EGG
# Metric similarity:  0.625
# Human similarity:   1.81
#
# Words:              FERTILITY - EGG
# Metric similarity:  0.15384615384615385
# Human similarity:   6.69
#
# Words:              STOCK - LIVE
# Metric similarity:  0.2857142857142857
# Human similarity:   3.73
#
# Words:              STOCK - LIFE
# Metric similarity:  0.6153846153846154
# Human similarity:   0.92
#
# Words:              BOOK - LIBRARY
# Metric similarity:  0.8
# Human similarity:   7.46
#
# Words:              BANK - MONEY
# Metric similarity:  0.5714285714285714
# Human similarity:   8.12
#
# Words:              WOOD - FOREST
# Metric similarity:  1.0
# Human similarity:   7.73
#
# Words:              MONEY - CASH
# Metric similarity:  0.875
# Human similarity:   9.15
#
# Words:              PROFESSOR - CUCUMBER
# Metric similarity:  0.5
# Human similarity:   0.31
#
# Words:              KING - CABBAGE
# Metric similarity:  0.5714285714285714
# Human similarity:   0.23
#
# Words:              KING - QUEEN
# Metric similarity:  1.0
# Human similarity:   8.58
#
# Words:              KING - ROOK
# Metric similarity:  0.9090909090909091
# Human similarity:   5.92
#
# Words:              BISHOP - RABBI
# Metric similarity:  0.8181818181818182
# Human similarity:   6.69
#
# Words:              JERUSALEM - ISRAEL
# Metric similarity:  0.0
# Human similarity:   8.46
#
# Words:              JERUSALEM - PALESTINIAN
# Metric similarity:  0.0
# Human similarity:   7.65
#
# Words:              HOLY - SEX
# Metric similarity:  0.3076923076923077
# Human similarity:   1.62
#
# Words:              FUCK - SEX
# Metric similarity:  0.8571428571428571
# Human similarity:   9.44
#
# Words:              MARADONA - FOOTBALL
# Metric similarity:  0
# Human similarity:   8.62
#
# Words:              FOOTBALL - SOCCER
# Metric similarity:  0.96
# Human similarity:   9.03
#
# Words:              FOOTBALL - BASKETBALL
# Metric similarity:  0.9
# Human similarity:   6.81
#
# Words:              FOOTBALL - TENNIS
# Metric similarity:  0.782608695652174
# Human similarity:   6.63
#
# Words:              TENNIS - RACKET
# Metric similarity:  0.5714285714285714
# Human similarity:   7.56
#
# Words:              ARAFAT - PEACE
# Metric similarity:  0.0
# Human similarity:   6.73
#
# Words:              ARAFAT - TERROR
# Metric similarity:  0.0
# Human similarity:   7.65
#
# Words:              ARAFAT - JACKSON
# Metric similarity:  0.0
# Human similarity:   2.50
#
# Words:              LAW - LAWYER
# Metric similarity:  0.13333333333333333
# Human similarity:   8.38
#
# Words:              MOVIE - STAR
# Metric similarity:  0.5333333333333333
# Human similarity:   7.38
#
# Words:              MOVIE - POPCORN
# Metric similarity:  0.36363636363636365
# Human similarity:   6.19
#
# Words:              MOVIE - CRITIC
# Metric similarity:  0.4444444444444444
# Human similarity:   6.73
#
# Words:              MOVIE - THEATER
# Metric similarity:  0.625
# Human similarity:   7.92
#
# Words:              PHYSICS - PROTON
# Metric similarity:  0.2
# Human similarity:   8.12
#
# Words:              PHYSICS - CHEMISTRY
# Metric similarity:  0.9
# Human similarity:   7.35
#
# Words:              SPACE - CHEMISTRY
# Metric similarity:  0.4444444444444444
# Human similarity:   4.88
#
# Words:              ALCOHOL - CHEMISTRY
# Metric similarity:  0.7142857142857143
# Human similarity:   5.54
#
# Words:              VODKA - GIN
# Metric similarity:  0.9090909090909091
# Human similarity:   8.46
#
# Words:              VODKA - BRANDY
# Metric similarity:  0.9090909090909091
# Human similarity:   8.13
#
# Words:              DRINK - CAR
# Metric similarity:  0.26666666666666666
# Human similarity:   3.04
#
# Words:              DRINK - EAR
# Metric similarity:  0.46153846153846156
# Human similarity:   1.31
#
# Words:              DRINK - MOUTH
# Metric similarity:  0.5
# Human similarity:   5.96
#
# Words:              DRINK - EAT
# Metric similarity:  0.5
# Human similarity:   6.87
#
# Words:              BABY - MOTHER
# Metric similarity:  0.8181818181818182
# Human similarity:   7.85
#
# Words:              DRINK - MOTHER
# Metric similarity:  0.5333333333333333
# Human similarity:   2.65
#
# Words:              CAR - AUTOMOBILE
# Metric similarity:  1.0
# Human similarity:   8.94
#
# Words:              GEM - JEWEL
# Metric similarity:  1.0
# Human similarity:   8.96
#
# Words:              JOURNEY - VOYAGE
# Metric similarity:  0.9523809523809523
# Human similarity:   9.29
#
# Words:              BOY - LAD
# Metric similarity:  0.9473684210526315
# Human similarity:   8.83
#
# Words:              COAST - SHORE
# Metric similarity:  0.9090909090909091
# Human similarity:   9.10
#
# Words:              ASYLUM - MADHOUSE
# Metric similarity:  0.9523809523809523
# Human similarity:   8.87
#
# Words:              MAGICIAN - WIZARD
# Metric similarity:  1.0
# Human similarity:   9.02
#
# Words:              MIDDAY - NOON
# Metric similarity:  1.0
# Human similarity:   9.29
#
# Words:              FURNACE - STOVE
# Metric similarity:  0.5263157894736842
# Human similarity:   8.79
#
# Words:              FOOD - FRUIT
# Metric similarity:  0.4
# Human similarity:   7.52
#
# Words:              BIRD - COCK
# Metric similarity:  0.9523809523809523
# Human similarity:   7.10
#
# Words:              BIRD - CRANE
# Metric similarity:  0.8695652173913043
# Human similarity:   7.38
#
# Words:              TOOL - IMPLEMENT
# Metric similarity:  0.9333333333333333
# Human similarity:   6.46
#
# Words:              BROTHER - MONK
# Metric similarity:  0.9523809523809523
# Human similarity:   6.27
#
# Words:              CRANE - IMPLEMENT
# Metric similarity:  0.75
# Human similarity:   2.69
#
# Words:              LAD - BROTHER
# Metric similarity:  0.7777777777777778
# Human similarity:   4.46
#
# Words:              JOURNEY - CAR
# Metric similarity:  0.1
# Human similarity:   5.85
#
# Words:              MONK - ORACLE
# Metric similarity:  0.6666666666666666
# Human similarity:   5.00
#
# Words:              CEMETERY - WOODLAND
# Metric similarity:  0.4
# Human similarity:   2.08
#
# Words:              FOOD - ROOSTER
# Metric similarity:  0.21052631578947367
# Human similarity:   4.42
#
# Words:              COAST - HILL
# Metric similarity:  0.6666666666666666
# Human similarity:   4.38
#
# Words:              FOREST - GRAVEYARD
# Metric similarity:  0.4
# Human similarity:   1.85
#
# Words:              SHORE - WOODLAND
# Metric similarity:  0.5454545454545454
# Human similarity:   3.08
#
# Words:              MONK - SLAVE
# Metric similarity:  0.7777777777777778
# Human similarity:   0.92
#
# Words:              COAST - FOREST
# Metric similarity:  0.5
# Human similarity:   3.15
#
# Words:              LAD - WIZARD
# Metric similarity:  0.7777777777777778
# Human similarity:   0.92
#
# Words:              CHORD - SMILE
# Metric similarity:  0.375
# Human similarity:   0.54
#
# Words:              GLASS - MAGICIAN
# Metric similarity:  0.47058823529411764
# Human similarity:   2.08
#
# Words:              NOON - STRING
# Metric similarity:  0.26666666666666666
# Human similarity:   0.54
#
# Words:              ROOSTER - VOYAGE
# Metric similarity:  0.08
# Human similarity:   0.62
#
# Words:              MONEY - DOLLAR
# Metric similarity:  0.7777777777777778
# Human similarity:   8.42
#
# Words:              MONEY - CASH
# Metric similarity:  0.875
# Human similarity:   9.08
#
# Words:              MONEY - CURRENCY
# Metric similarity:  0.9333333333333333
# Human similarity:   9.04
#
# Words:              MONEY - WEALTH
# Metric similarity:  0.9230769230769231
# Human similarity:   8.27
#
# Words:              MONEY - PROPERTY
# Metric similarity:  0.8333333333333334
# Human similarity:   7.57
#
# Words:              MONEY - POSSESSION
# Metric similarity:  0.7272727272727273
# Human similarity:   7.29
#
# Words:              MONEY - BANK
# Metric similarity:  0.5714285714285714
# Human similarity:   8.50
#
# Words:              MONEY - DEPOSIT
# Metric similarity:  0.875
# Human similarity:   7.73
#
# Words:              MONEY - WITHDRAWAL
# Metric similarity:  0.2857142857142857
# Human similarity:   6.88
#
# Words:              MONEY - LAUNDERING
# Metric similarity:  0.25
# Human similarity:   5.65
#
# Words:              MONEY - OPERATION
# Metric similarity:  0.3333333333333333
# Human similarity:   3.31
#
# Words:              TIGER - JAGUAR
# Metric similarity:  0.9333333333333333
# Human similarity:   8.00
#
# Words:              TIGER - FELINE
# Metric similarity:  0.9285714285714286
# Human similarity:   8.00
#
# Words:              TIGER - CARNIVORE
# Metric similarity:  0.8888888888888888
# Human similarity:   7.08
#
# Words:              TIGER - MAMMAL
# Metric similarity:  0.8
# Human similarity:   6.85
#
# Words:              TIGER - ANIMAL
# Metric similarity:  0.8
# Human similarity:   7.00
#
# Words:              TIGER - ORGANISM
# Metric similarity:  0.8571428571428571
# Human similarity:   4.77
#
# Words:              TIGER - FAUNA
# Metric similarity:  0.8
# Human similarity:   5.62
#
# Words:              TIGER - ZOO
# Metric similarity:  0.5333333333333333
# Human similarity:   5.87
#
# Words:              PSYCHOLOGY - PSYCHIATRY
# Metric similarity:  0.7272727272727273
# Human similarity:   8.08
#
# Words:              PSYCHOLOGY - ANXIETY
# Metric similarity:  0.25
# Human similarity:   7.00
#
# Words:              PSYCHOLOGY - FEAR
# Metric similarity:  0.25
# Human similarity:   6.85
#
# Words:              PSYCHOLOGY - DEPRESSION
# Metric similarity:  0.35294117647058826
# Human similarity:   7.42
#
# Words:              PSYCHOLOGY - CLINIC
# Metric similarity:  0.23529411764705882
# Human similarity:   6.58
#
# Words:              PSYCHOLOGY - DOCTOR
# Metric similarity:  0.3333333333333333
# Human similarity:   6.42
#
# Words:              PSYCHOLOGY - FREUD
# Metric similarity:  0.0
# Human similarity:   8.21
#
# Words:              PSYCHOLOGY - MIND
# Metric similarity:  0.5882352941176471
# Human similarity:   7.69
#
# Words:              PSYCHOLOGY - HEALTH
# Metric similarity:  0.26666666666666666
# Human similarity:   7.23
#
# Words:              PSYCHOLOGY - SCIENCE
# Metric similarity:  0.9411764705882353
# Human similarity:   6.71
#
# Words:              PSYCHOLOGY - DISCIPLINE
# Metric similarity:  0.875
# Human similarity:   5.58
#
# Words:              PSYCHOLOGY - COGNITION
# Metric similarity:  0.6153846153846154
# Human similarity:   7.48
#
# Words:              PLANET - STAR
# Metric similarity:  0.8571428571428571
# Human similarity:   8.45
#
# Words:              PLANET - CONSTELLATION
# Metric similarity:  0.7692307692307693
# Human similarity:   8.06
#
# Words:              PLANET - MOON
# Metric similarity:  0.8
# Human similarity:   8.08
#
# Words:              PLANET - SUN
# Metric similarity:  0.8
# Human similarity:   8.02
#
# Words:              PLANET - GALAXY
# Metric similarity:  0.631578947368421
# Human similarity:   8.11
#
# Words:              PLANET - SPACE
# Metric similarity:  0.5333333333333333
# Human similarity:   7.92
#
# Words:              PLANET - ASTRONOMER
# Metric similarity:  0.7368421052631579
# Human similarity:   7.94
#
# Words:              PRECEDENT - EXAMPLE
# Metric similarity:  0.9230769230769231
# Human similarity:   5.85
#
# Words:              PRECEDENT - INFORMATION
# Metric similarity:  0.8333333333333334
# Human similarity:   3.85
#
# Words:              PRECEDENT - COGNITION
# Metric similarity:  0.7272727272727273
# Human similarity:   2.81
#
# Words:              PRECEDENT - LAW
# Metric similarity:  0.9090909090909091
# Human similarity:   6.65
#
# Words:              PRECEDENT - COLLECTION
# Metric similarity:  0.8
# Human similarity:   2.50
#
# Words:              PRECEDENT - GROUP
# Metric similarity:  0.6666666666666666
# Human similarity:   1.77
#
# Words:              PRECEDENT - ANTECEDENT
# Metric similarity:  0.6153846153846154
# Human similarity:   6.04
#
# Words:              CUP - COFFEE
# Metric similarity:  0.7619047619047619
# Human similarity:   6.58
#
# Words:              CUP - TABLEWARE
# Metric similarity:  0.8888888888888888
# Human similarity:   6.85
#
# Words:              CUP - ARTICLE
# Metric similarity:  0.75
# Human similarity:   2.40
#
# Words:              CUP - ARTIFACT
# Metric similarity:  0.7692307692307693
# Human similarity:   2.92
#
# Words:              CUP - OBJECT
# Metric similarity:  0.5454545454545454
# Human similarity:   3.69
#
# Words:              CUP - ENTITY
# Metric similarity:  0.2857142857142857
# Human similarity:   2.15
#
# Words:              CUP - DRINK
# Metric similarity:  0.8
# Human similarity:   7.25
#
# Words:              CUP - FOOD
# Metric similarity:  0.5882352941176471
# Human similarity:   5.00
#
# Words:              CUP - SUBSTANCE
# Metric similarity:  0.5882352941176471
# Human similarity:   1.92
#
# Words:              CUP - LIQUID
# Metric similarity:  0.7368421052631579
# Human similarity:   5.90
#
# Words:              JAGUAR - CAT
# Metric similarity:  0.9655172413793104
# Human similarity:   7.42
#
# Words:              JAGUAR - CAR
# Metric similarity:  0.32
# Human similarity:   7.27
#
# Words:              ENERGY - SECRETARY
# Metric similarity:  0.23529411764705882
# Human similarity:   1.81
#
# Words:              SECRETARY - SENATE
# Metric similarity:  0.1111111111111111
# Human similarity:   5.06
#
# Words:              ENERGY - LABORATORY
# Metric similarity:  0.3076923076923077
# Human similarity:   5.09
#
# Words:              COMPUTER - LABORATORY
# Metric similarity:  0.4
# Human similarity:   6.78
#
# Words:              WEAPON - SECRET
# Metric similarity:  0.2857142857142857
# Human similarity:   6.06
#
# Words:              FBI - FINGERPRINT
# Metric similarity:  0.23529411764705882
# Human similarity:   6.94
#
# Words:              FBI - INVESTIGATION
# Metric similarity:  0.2222222222222222
# Human similarity:   8.31
#
# Words:              INVESTIGATION - EFFORT
# Metric similarity:  0.8235294117647058
# Human similarity:   4.59
#
# Words:              MARS - WATER
# Metric similarity:  0.3333333333333333
# Human similarity:   2.94
#
# Words:              MARS - SCIENTIST
# Metric similarity:  0.14285714285714285
# Human similarity:   5.63
#
# Words:              NEWS - REPORT
# Metric similarity:  0.9230769230769231
# Human similarity:   8.16
#
# Words:              CANYON - LANDSCAPE
# Metric similarity:  0.35294117647058826
# Human similarity:   7.53
#
# Words:              IMAGE - SURFACE
# Metric similarity:  0.7142857142857143
# Human similarity:   4.56
#
# Words:              DISCOVERY - SPACE
# Metric similarity:  0.4
# Human similarity:   6.34
#
# Words:              WATER - SEEPAGE
# Metric similarity:  0.25
# Human similarity:   6.56
#
# Words:              SIGN - RECESS
# Metric similarity:  0.75
# Human similarity:   2.38
#
# Words:              WEDNESDAY - NEWS
# Metric similarity:  0.26666666666666666
# Human similarity:   2.22
#
# Words:              MILE - KILOMETER
# Metric similarity:  0.8
# Human similarity:   8.66
#
# Words:              COMPUTER - NEWS
# Metric similarity:  0.13333333333333333
# Human similarity:   4.47
#
# Words:              TERRITORY - SURFACE
# Metric similarity:  0.6153846153846154
# Human similarity:   5.34
#
# Words:              ATMOSPHERE - LANDSCAPE
# Metric similarity:  0.5
# Human similarity:   3.69
#
# Words:              PRESIDENT - MEDAL
# Metric similarity:  0.23529411764705882
# Human similarity:   3.00
#
# Words:              WAR - TROOPS
# Metric similarity:  0.3076923076923077
# Human similarity:   8.13
#
# Words:              RECORD - NUMBER
# Metric similarity:  0.9090909090909091
# Human similarity:   6.31
#
# Words:              SKIN - EYE
# Metric similarity:  0.6666666666666666
# Human similarity:   6.22
#
# Words:              JAPANESE - AMERICAN
# Metric similarity:  0.8421052631578947
# Human similarity:   6.50
#
# Words:              THEATER - HISTORY
# Metric similarity:  0.5
# Human similarity:   3.91
#
# Words:              VOLUNTEER - MOTTO
# Metric similarity:  0.125
# Human similarity:   2.56
#
# Words:              PREJUDICE - RECOGNITION
# Metric similarity:  0.6666666666666666
# Human similarity:   3.00
#
# Words:              DECORATION - VALOR
# Metric similarity:  0.26666666666666666
# Human similarity:   5.63
#
# Words:              CENTURY - YEAR
# Metric similarity:  0.8333333333333334
# Human similarity:   7.59
#
# Words:              CENTURY - NATION
# Metric similarity:  0.36363636363636365
# Human similarity:   3.16
#
# Words:              DELAY - RACISM
# Metric similarity:  0.625
# Human similarity:   1.19
#
# Words:              DELAY - NEWS
# Metric similarity:  0.5333333333333333
# Human similarity:   3.31
#
# Words:              MINISTER - PARTY
# Metric similarity:  0.7368421052631579
# Human similarity:   6.63
#
# Words:              PEACE - PLAN
# Metric similarity:  0.3076923076923077
# Human similarity:   4.75
#
# Words:              MINORITY - PEACE
# Metric similarity:  0.5714285714285714
# Human similarity:   3.69
#
# Words:              ATTEMPT - PEACE
# Metric similarity:  0.3076923076923077
# Human similarity:   4.25
#
# Words:              GOVERNMENT - CRISIS
# Metric similarity:  0.5333333333333333
# Human similarity:   6.56
#
# Words:              DEPLOYMENT - DEPARTURE
# Metric similarity:  0.7142857142857143
# Human similarity:   4.25
#
# Words:              DEPLOYMENT - WITHDRAWAL
# Metric similarity:  0.7777777777777778
# Human similarity:   5.88
#
# Words:              ENERGY - CRISIS
# Metric similarity:  0.625
# Human similarity:   5.94
#
# Words:              ANNOUNCEMENT - NEWS
# Metric similarity:  0.6666666666666666
# Human similarity:   7.56
#
# Words:              ANNOUNCEMENT - EFFORT
# Metric similarity:  0.3076923076923077
# Human similarity:   2.75
#
# Words:              STROKE - HOSPITAL
# Metric similarity:  0.4
# Human similarity:   7.03
#
# Words:              DISABILITY - DEATH
# Metric similarity:  0.5333333333333333
# Human similarity:   5.47
#
# Words:              VICTIM - EMERGENCY
# Metric similarity:  0.4444444444444444
# Human similarity:   6.47
#
# Words:              TREATMENT - RECOVERY
# Metric similarity:  0.7692307692307693
# Human similarity:   7.91
#
# Words:              JOURNAL - ASSOCIATION
# Metric similarity:  0.4
# Human similarity:   4.97
#
# Words:              DOCTOR - PERSONNEL
# Metric similarity:  0.26666666666666666
# Human similarity:   5.00
#
# Words:              DOCTOR - LIABILITY
# Metric similarity:  0.26666666666666666
# Human similarity:   5.19
#
# Words:              LIABILITY - INSURANCE
# Metric similarity:  0.625
# Human similarity:   7.03
#
# Words:              SCHOOL - CENTER
# Metric similarity:  0.875
# Human similarity:   3.44
#
# Words:              REASON - HYPERTENSION
# Metric similarity:  0.5555555555555556
# Human similarity:   2.31
#
# Words:              REASON - CRITERION
# Metric similarity:  0.5333333333333333
# Human similarity:   5.91
#
# Words:              HUNDRED - PERCENT
# Metric similarity:  0.25
# Human similarity:   7.38
#
# Words:              HARVARD - YALE
# Metric similarity:  0.0
# Human similarity:   8.13
#
# Words:              HOSPITAL - INFRASTRUCTURE
# Metric similarity:  0.26666666666666666
# Human similarity:   4.63
#
# Words:              DEATH - ROW
# Metric similarity:  0.5
# Human similarity:   5.25
#
# Words:              DEATH - INMATE
# Metric similarity:  0.23529411764705882
# Human similarity:   5.03
#
# Words:              LAWYER - EVIDENCE
# Metric similarity:  0.13333333333333333
# Human similarity:   6.69
#
# Words:              LIFE - DEATH
# Metric similarity:  0.8571428571428571
# Human similarity:   7.88
#
# Words:              LIFE - TERM
# Metric similarity:  0.8571428571428571
# Human similarity:   4.50
#
# Words:              WORD - SIMILARITY
# Metric similarity:  0.3333333333333333
# Human similarity:   4.75
#
# Words:              BOARD - RECOMMENDATION
# Metric similarity:  0.26666666666666666
# Human similarity:   4.47
#
# Words:              GOVERNOR - INTERVIEW
# Metric similarity:  0.1111111111111111
# Human similarity:   3.25
#
# Words:              OPEC - COUNTRY
# Metric similarity:  0.5555555555555556
# Human similarity:   5.63
#
# Words:              PEACE - ATMOSPHERE
# Metric similarity:  0.7142857142857143
# Human similarity:   3.69
#
# Words:              PEACE - INSURANCE
# Metric similarity:  0.8235294117647058
# Human similarity:   2.94
#
# Words:              TERRITORY - KILOMETER
# Metric similarity:  0.25
# Human similarity:   5.28
#
# Words:              TRAVEL - ACTIVITY
# Metric similarity:  0.6666666666666666
# Human similarity:   5.00
#
# Words:              COMPETITION - PRICE
# Metric similarity:  0.46153846153846156
# Human similarity:   6.44
#
# Words:              CONSUMER - CONFIDENCE
# Metric similarity:  0.125
# Human similarity:   4.13
#
# Words:              CONSUMER - ENERGY
# Metric similarity:  0.25
# Human similarity:   4.75
#
# Words:              PROBLEM - AIRPORT
# Metric similarity:  0.13333333333333333
# Human similarity:   2.38
#
# Words:              CAR - FLIGHT
# Metric similarity:  0.5555555555555556
# Human similarity:   4.94
#
# Words:              CREDIT - CARD
# Metric similarity:  0.6153846153846154
# Human similarity:   8.06
#
# Words:              CREDIT - INFORMATION
# Metric similarity:  0.7272727272727273
# Human similarity:   5.31
#
# Words:              HOTEL - RESERVATION
# Metric similarity:  0.375
# Human similarity:   8.03
#
# Words:              GROCERY - MONEY
# Metric similarity:  0.13333333333333333
# Human similarity:   5.94
#
# Words:              REGISTRATION - ARRANGEMENT
# Metric similarity:  0.6666666666666666
# Human similarity:   6.00
#
# Words:              ARRANGEMENT - ACCOMMODATION
# Metric similarity:  0.6666666666666666
# Human similarity:   5.41
#
# Words:              MONTH - HOTEL
# Metric similarity:  0.15384615384615385
# Human similarity:   1.81
#
# Words:              TYPE - KIND
# Metric similarity:  0.9473684210526315
# Human similarity:   8.97
#
# Words:              ARRIVAL - HOTEL
# Metric similarity:  0.47058823529411764
# Human similarity:   6.00
#
# Words:              BED - CLOSET
# Metric similarity:  0.8421052631578947
# Human similarity:   6.72
#
# Words:              CLOSET - CLOTHES
# Metric similarity:  0.5555555555555556
# Human similarity:   8.00
#
# Words:              SITUATION - CONCLUSION
# Metric similarity:  0.625
# Human similarity:   4.81
#
# Words:              SITUATION - ISOLATION
# Metric similarity:  0.7272727272727273
# Human similarity:   3.88
#
# Words:              IMPARTIALITY - INTEREST
# Metric similarity:  0.4
# Human similarity:   5.16
#
# Words:              DIRECTION - COMBINATION
# Metric similarity:  0.6666666666666666
# Human similarity:   2.25
#
# Words:              STREET - PLACE
# Metric similarity:  0.6153846153846154
# Human similarity:   6.44
#
# Words:              STREET - AVENUE
# Metric similarity:  0.9473684210526315
# Human similarity:   8.88
#
# Words:              STREET - BLOCK
# Metric similarity:  0.6666666666666666
# Human similarity:   6.88
#
# Words:              STREET - CHILDREN
# Metric similarity:  0.47058823529411764
# Human similarity:   4.94
#
# Words:              LISTING - PROXIMITY
# Metric similarity:  0.3157894736842105
# Human similarity:   2.56
#
# Words:              LISTING - CATEGORY
# Metric similarity:  0.375
# Human similarity:   6.38
#
# Words:              CELL - PHONE
# Metric similarity:  0.9
# Human similarity:   7.81
#
# Words:              PRODUCTION - HIKE
# Metric similarity:  0.5882352941176471
# Human similarity:   1.75
#
# Words:              BENCHMARK - INDEX
# Metric similarity:  0.7692307692307693
# Human similarity:   4.25
#
# Words:              MEDIA - TRADING
# Metric similarity:  0.625
# Human similarity:   3.88
#
# Words:              MEDIA - GAIN
# Metric similarity:  0.5
# Human similarity:   2.88
#
# Words:              DIVIDEND - PAYMENT
# Metric similarity:  0.8888888888888888
# Human similarity:   7.63
#
# Words:              DIVIDEND - CALCULATION
# Metric similarity:  0.2857142857142857
# Human similarity:   6.48
#
# Words:              CALCULATION - COMPUTATION
# Metric similarity:  1.0
# Human similarity:   8.44
#
# Words:              CURRENCY - MARKET
# Metric similarity:  0.3076923076923077
# Human similarity:   7.50
#
# Words:              OPEC - OIL
# Metric similarity:  0.2
# Human similarity:   8.59
#
# Words:              OIL - STOCK
# Metric similarity:  0.5555555555555556
# Human similarity:   6.34
#
# Words:              ANNOUNCEMENT - PRODUCTION
# Metric similarity:  0.5
# Human similarity:   3.38
#
# Words:              ANNOUNCEMENT - WARNING
# Metric similarity:  0.6153846153846154
# Human similarity:   6.00
#
# Words:              PROFIT - WARNING
# Metric similarity:  0.2857142857142857
# Human similarity:   3.88
#
# Words:              PROFIT - LOSS
# Metric similarity:  0.7058823529411765
# Human similarity:   7.63
#
# Words:              DOLLAR - YEN
# Metric similarity:  0.8
# Human similarity:   7.78
#
# Words:              DOLLAR - BUCK
# Metric similarity:  1.0
# Human similarity:   9.22
#
# Words:              DOLLAR - PROFIT
# Metric similarity:  0.3076923076923077
# Human similarity:   7.38
#
# Words:              DOLLAR - LOSS
# Metric similarity:  0.3333333333333333
# Human similarity:   6.09
#
# Words:              COMPUTER - SOFTWARE
# Metric similarity:  0.11764705882352941
# Human similarity:   8.50
#
# Words:              NETWORK - HARDWARE
# Metric similarity:  0.8
# Human similarity:   8.31
#
# Words:              PHONE - EQUIPMENT
# Metric similarity:  0.875
# Human similarity:   7.13
#
# Words:              EQUIPMENT - MAKER
# Metric similarity:  0.5
# Human similarity:   5.91
#
# Words:              LUXURY - CAR
# Metric similarity:  0.11764705882352941
# Human similarity:   6.47
#
# Words:              FIVE - MONTH
# Metric similarity:  0.46153846153846156
# Human similarity:   3.38
#
# Words:              REPORT - GAIN
# Metric similarity:  0.36363636363636365
# Human similarity:   3.63
#
# Words:              INVESTOR - EARNING
# Metric similarity:  0.0
# Human similarity:   7.13
#
# Words:              LIQUID - WATER
# Metric similarity:  0.9333333333333333
# Human similarity:   7.89
#
# Words:              BASEBALL - SEASON
# Metric similarity:  0.21052631578947367
# Human similarity:   5.97
#
# Words:              GAME - VICTORY
# Metric similarity:  0.5714285714285714
# Human similarity:   7.03
#
# Words:              GAME - TEAM
# Metric similarity:  0.3076923076923077
# Human similarity:   7.69
#
# Words:              MARATHON - SPRINT
# Metric similarity:  0.5
# Human similarity:   7.47
#
# Words:              GAME - SERIES
# Metric similarity:  0.8571428571428571
# Human similarity:   6.19
#
# Words:              GAME - DEFEAT
# Metric similarity:  0.5714285714285714
# Human similarity:   6.97
#
# Words:              SEVEN - SERIES
# Metric similarity:  0.375
# Human similarity:   3.56
#
# Words:              SEAFOOD - SEA
# Metric similarity:  0.36363636363636365
# Human similarity:   7.47
#
# Words:              SEAFOOD - FOOD
# Metric similarity:  0.9090909090909091
# Human similarity:   8.34
#
# Words:              SEAFOOD - LOBSTER
# Metric similarity:  0.8571428571428571
# Human similarity:   8.70
#
# Words:              LOBSTER - FOOD
# Metric similarity:  0.7692307692307693
# Human similarity:   7.81
#
# Words:              LOBSTER - WINE
# Metric similarity:  0.3333333333333333
# Human similarity:   5.70
#
# Words:              FOOD - PREPARATION
# Metric similarity:  0.5714285714285714
# Human similarity:   6.22
#
# Words:              VIDEO - ARCHIVE
# Metric similarity:  0.5555555555555556
# Human similarity:   6.34
#
# Words:              START - YEAR
# Metric similarity:  0.5454545454545454
# Human similarity:   4.06
#
# Words:              START - MATCH
# Metric similarity:  0.5714285714285714
# Human similarity:   4.47
#
# Words:              GAME - ROUND
# Metric similarity:  0.8888888888888888
# Human similarity:   5.97
#
# Words:              BOXING - ROUND
# Metric similarity:  0.7272727272727273
# Human similarity:   7.61
#
# Words:              CHAMPIONSHIP - TOURNAMENT
# Metric similarity:  0.8571428571428571
# Human similarity:   8.36
#
# Words:              FIGHTING - DEFEATING
# Metric similarity:  0.2857142857142857
# Human similarity:   7.41
#
# Words:              LINE - INSURANCE
# Metric similarity:  0.7142857142857143
# Human similarity:   2.69
#
# Words:              DAY - SUMMER
# Metric similarity:  0.7692307692307693
# Human similarity:   3.94
#
# Words:              SUMMER - DROUGHT
# Metric similarity:  0.7692307692307693
# Human similarity:   7.16
#
# Words:              SUMMER - NATURE
# Metric similarity:  0.3333333333333333
# Human similarity:   5.63
#
# Words:              DAY - DAWN
# Metric similarity:  0.8333333333333334
# Human similarity:   7.53
#
# Words:              NATURE - ENVIRONMENT
# Metric similarity:  0.5454545454545454
# Human similarity:   8.31
#
# Words:              ENVIRONMENT - ECOLOGY
# Metric similarity:  0.9230769230769231
# Human similarity:   8.81
#
# Words:              NATURE - MAN
# Metric similarity:  0.5333333333333333
# Human similarity:   6.25
#
# Words:              MAN - WOMAN
# Metric similarity:  0.8888888888888888
# Human similarity:   8.30
#
# Words:              MAN - GOVERNOR
# Metric similarity:  0.7777777777777778
# Human similarity:   5.25
#
# Words:              MURDER - MANSLAUGHTER
# Metric similarity:  0.9166666666666666
# Human similarity:   8.53
#
# Words:              SOAP - OPERA
# Metric similarity:  0.2222222222222222
# Human similarity:   7.94
#
# Words:              OPERA - PERFORMANCE
# Metric similarity:  0.3076923076923077
# Human similarity:   6.88
#
# Words:              LIFE - LESSON
# Metric similarity:  0.42857142857142855
# Human similarity:   5.94
#
# Words:              FOCUS - LIFE
# Metric similarity:  0.5333333333333333
# Human similarity:   4.06
#
# Words:              PRODUCTION - CREW
# Metric similarity:  0.36363636363636365
# Human similarity:   6.25
#
# Words:              TELEVISION - FILM
# Metric similarity:  0.7777777777777778
# Human similarity:   7.72
#
# Words:              LOVER - QUARREL
# Metric similarity:  0.4
# Human similarity:   6.19
#
# Words:              VIEWER - SERIAL
# Metric similarity:  0.5
# Human similarity:   2.97
#
# Words:              POSSIBILITY - GIRL
# Metric similarity:  0.13333333333333333
# Human similarity:   1.94
#
# Words:              POPULATION - DEVELOPMENT
# Metric similarity:  0.7272727272727273
# Human similarity:   3.75
#
# Words:              MORALITY - IMPORTANCE
# Metric similarity:  0.6666666666666666
# Human similarity:   3.31
#
# Words:              MORALITY - MARRIAGE
# Metric similarity:  0.5454545454545454
# Human similarity:   3.69
#
# Words:              MEXICO - BRAZIL
# Metric similarity:  0.0
# Human similarity:   7.44
#
# Words:              GENDER - EQUALITY
# Metric similarity:  0.46153846153846156
# Human similarity:   6.41
#
# Words:              CHANGE - ATTITUDE
# Metric similarity:  0.5454545454545454
# Human similarity:   5.44
#
# Words:              FAMILY - PLANNING
# Metric similarity:  0.3076923076923077
# Human similarity:   6.25
#
# Words:              OPERA - INDUSTRY
# Metric similarity:  0.26666666666666666
# Human similarity:   2.63
#
# Words:              SUGAR - APPROACH
# Metric similarity:  0.26666666666666666
# Human similarity:   0.88
#
# Words:              PRACTICE - INSTITUTION
# Metric similarity:  0.8333333333333334
# Human similarity:   3.19
#
# Words:              MINISTRY - CULTURE
# Metric similarity:  0.5333333333333333
# Human similarity:   4.69
#
# Words:              PROBLEM - CHALLENGE
# Metric similarity:  0.6153846153846154
# Human similarity:   6.75
#
# Words:              SIZE - PROMINENCE
# Metric similarity:  0.6153846153846154
# Human similarity:   5.31
#
# Words:              COUNTRY - CITIZEN
# Metric similarity:  0.4
# Human similarity:   7.31
#
# Words:              PLANET - PEOPLE
# Metric similarity:  0.18181818181818182
# Human similarity:   5.75
#
# Words:              DEVELOPMENT - ISSUE
# Metric similarity:  0.75
# Human similarity:   3.97
#
# Words:              EXPERIENCE - MUSIC
# Metric similarity:  0.6153846153846154
# Human similarity:   3.47
#
# Words:              MUSIC - PROJECT
# Metric similarity:  0.8
# Human similarity:   3.63
#
# Words:              GLASS - METAL
# Metric similarity:  0.5
# Human similarity:   5.56
#
# Words:              ALUMINUM - METAL
# Metric similarity:  0.9333333333333333
# Human similarity:   7.83
#
# Words:              CHANCE - CREDIBILITY
# Metric similarity:  0.5
# Human similarity:   3.88
#
# Words:              EXHIBIT - MEMORABILIA
# Metric similarity:  0.42857142857142855
# Human similarity:   5.31
#
# Words:              CONCERT - VIRTUOSO
# Metric similarity:  0.11764705882352941
# Human similarity:   6.81
#
# Words:              ROCK - JAZZ
# Metric similarity:  0.875
# Human similarity:   7.59
#
# Words:              MUSEUM - THEATER
# Metric similarity:  0.625
# Human similarity:   7.19
#
# Words:              OBSERVATION - ARCHITECTURE
# Metric similarity:  0.7058823529411765
# Human similarity:   4.38
#
# Words:              SPACE - WORLD
# Metric similarity:  0.5714285714285714
# Human similarity:   6.53
#
# Words:              PRESERVATION - WORLD
# Metric similarity:  0.5882352941176471
# Human similarity:   6.19
#
# Words:              ADMISSION - TICKET
# Metric similarity:  0.5714285714285714
# Human similarity:   7.69
#
# Words:              SHOWER - THUNDERSTORM
# Metric similarity:  0.7
# Human similarity:   6.31
#
# Words:              SHOWER - FLOOD
# Metric similarity:  0.6363636363636364
# Human similarity:   6.03
#
# Words:              WEATHER - FORECAST
# Metric similarity:  0.13333333333333333
# Human similarity:   8.34
#
# Words:              DISASTER - AREA
# Metric similarity:  0.5
# Human similarity:   6.25
#
# Words:              GOVERNOR - OFFICE
# Metric similarity:  0.5263157894736842
# Human similarity:   6.34
#
# Words:              ARCHITECTURE - CENTURY
# Metric similarity:  0.3076923076923077
# Human similarity:   3.78
